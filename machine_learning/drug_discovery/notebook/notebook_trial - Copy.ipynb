# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df, labels, test_size=.25, shuffle=True, random_state=42,stratify=labels)

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
rfc.fit(x_train,y_train.ravel())
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rfc.predict(x_test)

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.8819805194805195

# %%
# !pip install pycm
# Out:
# ...
# [notice] A new release of pip is available: 24.1.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pycm import *

# %%
cm = ConfusionMatrix(y_test.reshape(-1),y_pred)

# %%
print(cm)
# Out:
# Predict   0         1
# Actual
# 0         166       44
#
# 1         14        514
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.90199,0.94082)
# ACC Macro                                                         0.92141
# ARI                                                               0.69525
# AUNP                                                              0.88198
# AUNU                                                              0.88198
# Bangdiwala B                                                      0.87765
# Bennett S                                                         0.84282
# CBA                                                               0.85581
# CSI                                                               0.80367
# Chi-Squared                                                       475.49428
# Chi-Squared DF                                                    1
# ...

# %%
cm.Overall_MCC
# Out:
# 0.8026837432263727

# %%
import joblib

with open(r'E:\VS Code\machine_learning\drug_discovery\data\processed\random_forest_model.pkl', 'wb') as file:
    joblib.dump(rfc, file)
